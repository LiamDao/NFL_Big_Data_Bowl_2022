# %% [markdown]
# ### Read in libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# ### Read in and subset nflfastR datasets
#
# Note about EP vs. EPA
# - EPA is the difference between the Expected Points (EP) at the beginning of the play compared to end of the play. It measures the plays impact on the score of the game.

# %%
YEARS = [2018, 2019, 2020]

fastR = pd.DataFrame()

for i in YEARS:
    i_data = pd.read_csv('https://github.com/guga31bb/nflfastR-data/blob/master/data/' \
                         'play_by_play_' + str(i) + '.csv.gz?raw=True',
                         compression='gzip', low_memory=False)

    fastR = fastR.append(i_data, sort=True)
    
fastR.reset_index(drop = True, inplace = True)

# %%
fastR.shape
# Out:
# (144422, 372)

# %%
fastR = fastR[['play_id', 'old_game_id', 'ep', 'epa', 'punt_inside_twenty', 'punt_in_endzone', 
               'punt_out_of_bounds', 'punt_downed', 'punt_fair_catch', 'play_type', 'return_team', 'weather',
               'surface', 'wind']]

fastR.head(2)
# Out:
#    play_id  old_game_id season_type        ep  epa  punt_inside_twenty  \
# 0        1   2018090600         REG       NaN  NaN                 NaN
# 1       37   2018090600         REG  0.770222 -0.0                 0.0
#
#    punt_in_endzone  punt_out_of_bounds  punt_downed  punt_fair_catch  \
# 0              NaN                 NaN          NaN              NaN
# 1              0.0                 0.0          0.0              0.0
#
#   play_type return_team                                            weather  \
# 0       NaN         NaN  Cloudy Temp: 81° F, Humidity: 71%, Wind: NNW 8...
# 1   kickoff         NaN  Cloudy Temp: 81° F, Humidity: 71%, Wind: NNW 8...
#
#   surface  wind
# 0   grass   8.0
# 1   grass   8.0

# %%
fastR = fastR[fastR['play_type'] == 'punt']
fastR = fastR.drop('play_type', axis = 1)

# %%
fastR.shape
# Out:
# (6526, 14)

# %%
# Rename columns to eventually merge with Kaggle data
fastR = fastR.rename(columns = {'play_id' : 'playId', 'old_game_id' : 'gameId'})
fastR.head(2)
# Out:
#     playId      gameId season_type        ep       epa  punt_inside_twenty  \
# 16     366  2018090600         REG -2.117271 -0.758654                 0.0
# 35     872  2018090600         REG -0.936326  0.410948                 0.0
#
#     punt_in_endzone  punt_out_of_bounds  punt_downed  punt_fair_catch  \
# 16              0.0                 0.0          0.0              0.0
# 35              0.0                 0.0          0.0              0.0
#
#    return_team                                            weather surface  \
# 16         ATL  Cloudy Temp: 81° F, Humidity: 71%, Wind: NNW 8...   grass
# 35         NaN  Cloudy Temp: 81° F, Humidity: 71%, Wind: NNW 8...   grass
#
#     wind
# 16   8.0
# 35   8.0

# %% [markdown]
# ### Read in and subset datasets from NFL Big Data Bowl

# %%
YEARS = [2018, 2019, 2020]

tracking = pd.DataFrame()

for i in YEARS:
    i_data = pd.read_csv('C:\\Users\\cmcle\\Documents\\NFL Big Data Bowl\\tracking' + str(i) + '.csv')

    tracking = tracking.append(i_data, sort=True)
    
tracking.reset_index(drop = True, inplace = True)

# %%
tracking = tracking.drop_duplicates(['gameId', 'playId'])
tracking = tracking[['gameId', 'playId', 'displayName', 'nflId', 'a', 's', 'dir', 'dis', 'o', 'x', 'y']]
tracking.head(2)
# Out:
#           gameId  playId    displayName    nflId     a     s     dir   dis  \
# 0     2018123000      36  Justin Tucker  39470.0  1.33  4.36  128.44  0.43
# 2415  2018123000     373       Sam Koch  31018.0  0.00  0.00   11.60  0.00
#
#            o      x      y
# 0     130.42  41.32  29.45
# 2415   44.46  81.81  27.76

# %%
pff = pd.read_csv('C:\\Users\\cmcle\\Documents\\NFL Big Data Bowl\\PFFScoutingData.csv')
pff = pff[pff['kickType'].isin(['N', 'R', 'A'])]
pff = pff[['gameId', 'playId', 'hangTime', 'kickType']]
pff.head(2)
# Out:
#        gameId  playId  hangTime kickType
# 1  2018090600     366      4.46        N
# 4  2018090600     872      4.35        N

# %%
games = pd.read_csv('C:\\Users\\cmcle\\Documents\\NFL Big Data Bowl\\games.csv')
games = games[['gameId', 'season', 'week', 'homeTeamAbbr', 'visitorTeamAbbr']]
games.head(2)
# Out:
#        gameId  season  week homeTeamAbbr visitorTeamAbbr
# 0  2018090600    2018     1          PHI             ATL
# 1  2018090900    2018     1          BAL             BUF

# %%
plays = pd.read_csv('C:\\Users\\cmcle\\Documents\\NFL Big Data Bowl\\plays.csv')
plays = plays[plays['specialTeamsPlayType'] == 'Punt']
plays = plays[['gameId', 'playId', 'playDescription', 'quarter', 'down', 'yardsToGo', 'specialTeamsPlayType',
              'kickLength', 'playResult', 'kickReturnYardage']]
plays.head(2)
# Out:
#        gameId  playId                                    playDescription  \
# 1  2018090600     366  (9:20) C.Johnston punts 56 yards to ATL 36, Ce...
# 4  2018090600     872  (:33) C.Johnston punts 65 yards to end zone, C...
#
#    quarter  down  yardsToGo specialTeamsPlayType  kickLength  playResult  \
# 1        1     4          4                 Punt        56.0          36
# 4        1     4         18                 Punt        65.0          45
#
#    kickReturnYardage
# 1                5.0
# 4                NaN

# %%
players = pd.read_csv('C:\\Users\\cmcle\\Documents\\NFL Big Data Bowl\\players.csv')
players = players[['nflId', 'collegeName', 'Position']]
players.head(2)
# Out:
#    nflId       collegeName Position
# 0  42901     James Madison       SS
# 1  43501  Central Michigan       FS

# %% [markdown]
# ### Merge datasets together

# %%
main = tracking.merge(players, on = ['nflId'])
main.head(2)
# Out:
#        gameId  playId    displayName    nflId     a     s     dir   dis  \
# 0  2018123000      36  Justin Tucker  39470.0  1.33  4.36  128.44  0.43
# 1  2018123000     392  Justin Tucker  39470.0  0.97  3.72  129.40  0.37
#
#         o      x      y collegeName Position
# 0  130.42  41.32  29.45       Texas        K
# 1  113.74  40.67  31.97       Texas        K

# %%
main = main.merge(plays, on = ['gameId', 'playId'])
main.head(2)
# Out:
#        gameId  playId displayName    nflId    a    s     dir  dis       o  \
# 0  2018123000    2165    Sam Koch  31018.0  0.0  0.0  268.97  0.0  278.65
# 1  2018123000    2502    Sam Koch  31018.0  0.0  0.0  191.59  0.0   84.96
#
#        x      y collegeName Position  \
# 0  65.77  28.85    Nebraska        P
# 1  28.35  28.21    Nebraska        P
#
#                                      playDescription  quarter  down  \
# 0  (:42) (Punt formation) S.Koch punts 36 yards t...        2     4
# 1  (12:50) (Punt formation) S.Koch punts 53 yards...        3     4
#
#    yardsToGo specialTeamsPlayType  kickLength  playResult  kickReturnYardage
# 0         17                 Punt        36.0          36                NaN
# 1         14                 Punt        53.0          16               37.0

# %%
main = main.merge(games, on = 'gameId')
main.head(2)
# Out:
#        gameId  playId displayName    nflId    a    s     dir  dis       o  \
# 0  2018123000    2165    Sam Koch  31018.0  0.0  0.0  268.97  0.0  278.65
# 1  2018123000    2502    Sam Koch  31018.0  0.0  0.0  191.59  0.0   84.96
#
#        x      y collegeName Position  \
# 0  65.77  28.85    Nebraska        P
# 1  28.35  28.21    Nebraska        P
#
#                                      playDescription  quarter  down  \
# 0  (:42) (Punt formation) S.Koch punts 36 yards t...        2     4
# 1  (12:50) (Punt formation) S.Koch punts 53 yards...        3     4
#
#    yardsToGo specialTeamsPlayType  kickLength  playResult  kickReturnYardage  \
# 0         17                 Punt        36.0          36                NaN
# 1         14                 Punt        53.0          16               37.0
#
#    season  week homeTeamAbbr visitorTeamAbbr
# 0    2018    17          BAL             CLE
# 1    2018    17          BAL             CLE

# %%
main = main.merge(pff, on = ['gameId', 'playId'])
main.head(2)
# Out:
#        gameId  playId displayName    nflId    a    s     dir  dis       o  \
# 0  2018123000    2165    Sam Koch  31018.0  0.0  0.0  268.97  0.0  278.65
# 1  2018123000    2502    Sam Koch  31018.0  0.0  0.0  191.59  0.0   84.96
#
#        x      y collegeName Position  \
# 0  65.77  28.85    Nebraska        P
# 1  28.35  28.21    Nebraska        P
#
#                                      playDescription  quarter  down  \
# 0  (:42) (Punt formation) S.Koch punts 36 yards t...        2     4
# 1  (12:50) (Punt formation) S.Koch punts 53 yards...        3     4
#
#    yardsToGo specialTeamsPlayType  kickLength  playResult  kickReturnYardage  \
# 0         17                 Punt        36.0          36                NaN
# 1         14                 Punt        53.0          16               37.0
#
#    season  week homeTeamAbbr visitorTeamAbbr  hangTime kickType
# 0    2018    17          BAL             CLE      4.56        A
# 1    2018    17          BAL             CLE      4.17        N

# %%
main = main.merge(fastR, on = ['gameId', 'playId'])
main.head(2)
# Out:
#        gameId  playId displayName    nflId    a    s     dir  dis       o  \
# 0  2018123000    2165    Sam Koch  31018.0  0.0  0.0  268.97  0.0  278.65
# 1  2018123000    2502    Sam Koch  31018.0  0.0  0.0  191.59  0.0   84.96
#
#        x      y collegeName Position  \
# 0  65.77  28.85    Nebraska        P
# 1  28.35  28.21    Nebraska        P
#
#                                      playDescription  quarter  down  \
# 0  (:42) (Punt formation) S.Koch punts 36 yards t...        2     4
# 1  (12:50) (Punt formation) S.Koch punts 53 yards...        3     4
#
#    yardsToGo specialTeamsPlayType  kickLength  playResult  kickReturnYardage  \
# 0         17                 Punt        36.0          36                NaN
# 1         14                 Punt        53.0          16               37.0
#
#    season  week homeTeamAbbr visitorTeamAbbr  hangTime kickType season_type  \
# 0    2018    17          BAL             CLE      4.56        A         REG
# 1    2018    17          BAL             CLE      4.17        N         REG
#
#          ep       epa  punt_inside_twenty  punt_in_endzone  \
# 0  0.372952 -0.331417                 1.0              0.0
# 1 -0.903790 -1.739167                 0.0              0.0
#
#    punt_out_of_bounds  punt_downed  punt_fair_catch return_team  \
# 0                 0.0          1.0              0.0         CLE
# 1                 0.0          0.0              0.0         CLE
#
#                                              weather surface  wind
# 0  Partly Cloudy Temp: 48° F, Humidity: 59%, Wind...   grass   2.0
# 1  Partly Cloudy Temp: 48° F, Humidity: 59%, Wind...   grass   2.0

# %%
# Reorganize columns
main = main[['gameId', 'season', 'season_type', 'week', 'homeTeamAbbr', 'visitorTeamAbbr', 'playId', 
             'quarter', 'down', 'yardsToGo', 'nflId', 'displayName', 'Position', 'collegeName', 'playDescription',
             'specialTeamsPlayType', 'playResult', 'ep', 'epa', 'kickReturnYardage', 'kickType', 'hangTime', 
             'kickLength', 'punt_inside_twenty', 'punt_in_endzone', 
            'punt_out_of_bounds', 'punt_downed', 'punt_fair_catch', 'return_team', 'weather', 'surface', 'wind',
            'a', 's', 'dir', 'dis', 'o', 'x', 'y']]
main.head(2)
# Out:
#        gameId  season season_type  week homeTeamAbbr visitorTeamAbbr  playId  \
# 0  2018123000    2018         REG    17          BAL             CLE    2165
# 1  2018123000    2018         REG    17          BAL             CLE    2502
#
#    quarter  down  yardsToGo    nflId displayName Position collegeName  \
# 0        2     4         17  31018.0    Sam Koch        P    Nebraska
# 1        3     4         14  31018.0    Sam Koch        P    Nebraska
#
#                                      playDescription specialTeamsPlayType  \
# 0  (:42) (Punt formation) S.Koch punts 36 yards t...                 Punt
# 1  (12:50) (Punt formation) S.Koch punts 53 yards...                 Punt
#
#    playResult        ep       epa  kickReturnYardage kickType  hangTime  \
# 0          36  0.372952 -0.331417                NaN        A      4.56
# 1          16 -0.903790 -1.739167               37.0        N      4.17
#
#    kickLength  punt_inside_twenty  punt_in_endzone  punt_out_of_bounds  \
# 0        36.0                 1.0              0.0                 0.0
# 1        53.0                 0.0              0.0                 0.0
#
#    punt_downed  punt_fair_catch return_team  \
# 0          1.0              0.0         CLE
# 1          0.0              0.0         CLE
#
#                                              weather surface  wind    a    s  \
# 0  Partly Cloudy Temp: 48° F, Humidity: 59%, Wind...   grass   2.0  0.0  0.0
# 1  Partly Cloudy Temp: 48° F, Humidity: 59%, Wind...   grass   2.0  0.0  0.0
#
#       dir  dis       o      x      y
# 0  268.97  0.0  278.65  65.77  28.85
# 1  191.59  0.0   84.96  28.35  28.21

# %% [markdown]
# ### Preliminary Analysis and Create New Variables

# %%
# Correlation Matrix
main.corr().style.background_gradient(cmap = 'coolwarm')
# Out:
# C:\Users\cmcle\anaconda3\lib\site-packages\pandas\io\formats\style.py:1264: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(s.to_numpy()) if vmin is None else vmin
# C:\Users\cmcle\anaconda3\lib\site-packages\pandas\io\formats\style.py:1265: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(s.to_numpy()) if vmax is None else vmax
# <style  type="text/css" >
# #T_9ba6c_row0_col0,#T_9ba6c_row1_col1,#T_9ba6c_row2_col2,#T_9ba6c_row3_col3,#T_9ba6c_row4_col4,#T_9ba6c_row6_col6,#T_9ba6c_row7_col7,#T_9ba6c_row8_col8,#T_9ba6c_row9_col9,#T_9ba6c_row10_col10,#T_9ba6c_row11_col11,#T_9ba6c_row12_col12,#T_9ba6c_row13_col13,#T_9ba6c_row14_col14,#T_9ba6c_row15_col15,#T_9ba6c_row16_col16,#T_9ba6c_row17_col17,#T_9ba6c_row18_col18,#T_9ba6c_row19_col19,#T_9ba6c_row20_col20,#T_9ba6c_row21_col21,#T_9ba6c_row22_col22,#T_9ba6c_row23_col23,#T_9ba6c_row24_col24,#T_9ba6c_row25_col25,#T_9ba6c_row26_col26{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_9ba6c_row0_col1,#T_9ba6c_row1_col0{
#             background-color:  #b70d28;
#             color:  #f1f1f1;
#         }#T_9ba6c_row0_col2,#T_9ba6c_row4_col12{
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }#T_9ba6c_row0_col3,#T_9ba6c_row0_col22,#T_9ba6c_row1_col22,#T_9ba6c_row6_col2,#T_9ba6c_row7_col25,#T_9ba6c_row8_col1,#T_9ba6c_row8_col2,#T_9ba6c_row8_col7,#T_9ba6c_row10_col2,#T_9ba6c_row11_col0,#T_9ba6c_row12_col25,#T_9ba6c_row13_col20,#T_9ba6c_row14_col24,#T_9ba6c_row17_col23,#T_9ba6c_row18_col25,#T_9ba6c_row20_col3,#T_9ba6c_row21_col24,#T_9ba6c_row22_col21,#T_9ba6c_row24_col2,#T_9ba6c_row24_col20,#T_9ba6c_row26_col25{
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }#T_9ba6c_row0_col4,#T_9ba6c_row1_col4,#T_9ba6c_row4_col26,#T_9ba6c_row6_col20,#T_9ba6c_row7_col3,#T_9ba6c_row8_col15,#T_9ba6c_row8_col19,#T_9ba6c_row8_col25,#T_9ba6c_row9_col1,#T_9ba6c_row10_col7,#T_9ba6c_row11_col1,#T_9ba6c_row11_col3,#T_9ba6c_row11_col4,#T_9ba6c_row12_col26,#T_9ba6c_row13_col19,#T_9ba6c_row13_col21,#T_9ba6c_row14_col4,#T_9ba6c_row14_col15,#T_9ba6c_row14_col21,#T_9ba6c_row15_col7,#T_9ba6c_row18_col3,#T_9ba6c_row18_col21,#T_9ba6c_row20_col4,#T_9ba6c_row21_col19,#T_9ba6c_row22_col3,#T_9ba6c_row23_col19,#T_9ba6c_row24_col3,#T_9ba6c_row26_col7{
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }#T_9ba6c_row0_col5,#T_9ba6c_row1_col5,#T_9ba6c_row2_col5,#T_9ba6c_row3_col5,#T_9ba6c_row4_col5,#T_9ba6c_row5_col0,#T_9ba6c_row5_col1,#T_9ba6c_row5_col2,#T_9ba6c_row5_col3,#T_9ba6c_row5_col4,#T_9ba6c_row5_col5,#T_9ba6c_row5_col6,#T_9ba6c_row5_col7,#T_9ba6c_row5_col8,#T_9ba6c_row5_col9,#T_9ba6c_row5_col10,#T_9ba6c_row5_col11,#T_9ba6c_row5_col12,#T_9ba6c_row5_col13,#T_9ba6c_row5_col14,#T_9ba6c_row5_col15,#T_9ba6c_row5_col16,#T_9ba6c_row5_col17,#T_9ba6c_row5_col18,#T_9ba6c_row5_col19,#T_9ba6c_row5_col20,#T_9ba6c_row5_col21,#T_9ba6c_row5_col22,#T_9ba6c_row5_col23,#T_9ba6c_row5_col24,#T_9ba6c_row5_col25,#T_9ba6c_row5_col26,#T_9ba6c_row6_col5,#T_9ba6c_row7_col5,#T_9ba6c_row8_col5,#T_9ba6c_row9_col5,#T_9ba6c_row10_col5,#T_9ba6c_row11_col5,#T_9ba6c_row11_col16,#T_9ba6c_row11_col17,#T_9ba6c_row11_col18,#T_9ba6c_row12_col5,#T_9ba6c_row13_col5,#T_9ba6c_row14_col5,#T_9ba6c_row15_col5,#T_9ba6c_row16_col5,#T_9ba6c_row16_col11,#T_9ba6c_row17_col5,#T_9ba6c_row17_col11,#T_9ba6c_row18_col5,#T_9ba6c_row18_col11,#T_9ba6c_row19_col5,#T_9ba6c_row20_col5,#T_9ba6c_row21_col5,#T_9ba6c_row22_col5,#T_9ba6c_row23_col5,#T_9ba6c_row24_col5,#T_9ba6c_row25_col5,#T_9ba6c_row26_col5{
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }#T_9ba6c_row0_col6,#T_9ba6c_row1_col6,#T_9ba6c_row2_col6,#T_9ba6c_row3_col14,#T_9ba6c_row7_col6,#T_9ba6c_row14_col12,#T_9ba6c_row22_col14,#T_9ba6c_row24_col18{
#             background-color:  #80a3fa;
#             color:  #000000;
#         }#T_9ba6c_row0_col7,#T_9ba6c_row7_col1,#T_9ba6c_row9_col8,#T_9ba6c_row10_col6{
#             background-color:  #a1c0ff;
#             color:  #000000;
#         }#T_9ba6c_row0_col8,#T_9ba6c_row4_col11,#T_9ba6c_row7_col8,#T_9ba6c_row17_col10,#T_9ba6c_row25_col8{
#             background-color:  #cbd8ee;
#             color:  #000000;
#         }#T_9ba6c_row0_col9,#T_9ba6c_row1_col9,#T_9ba6c_row21_col13,#T_9ba6c_row22_col13,#T_9ba6c_row26_col9{
#             background-color:  #8db0fe;
#             color:  #000000;
#         }#T_9ba6c_row0_col10,#T_9ba6c_row18_col10,#T_9ba6c_row22_col10,#T_9ba6c_row24_col10{
#             background-color:  #c1d4f4;
#             color:  #000000;
#         }#T_9ba6c_row0_col11,#T_9ba6c_row1_col8,#T_9ba6c_row1_col11,#T_9ba6c_row2_col11,#T_9ba6c_row22_col8{
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }#T_9ba6c_row0_col12,#T_9ba6c_row8_col16{
#             background-color:  #6b8df0;
#             color:  #000000;
#         }#T_9ba6c_row0_col13,#T_9ba6c_row1_col13,#T_9ba6c_row4_col6,#T_9ba6c_row15_col13{
#             background-color:  #96b7ff;
#             color:  #000000;
#         }#T_9ba6c_row0_col14,#T_9ba6c_row2_col14,#T_9ba6c_row7_col16,#T_9ba6c_row22_col17{
#             background-color:  #799cf8;
#             color:  #000000;
#         }#T_9ba6c_row0_col15,#T_9ba6c_row0_col20,#T_9ba6c_row0_col24,#T_9ba6c_row1_col15,#T_9ba6c_row1_col20,#T_9ba6c_row2_col24,#T_9ba6c_row3_col22,#T_9ba6c_row4_col22,#T_9ba6c_row4_col25,#T_9ba6c_row8_col11,#T_9ba6c_row9_col6,#T_9ba6c_row9_col7,#T_9ba6c_row9_col13,#T_9ba6c_row9_col23,#T_9ba6c_row10_col3,#T_9ba6c_row10_col4,#T_9ba6c_row11_col8,#T_9ba6c_row11_col10,#T_9ba6c_row11_col14,#T_9ba6c_row12_col2,#T_9ba6c_row12_col19,#T_9ba6c_row13_col9,#T_9ba6c_row13_col18,#T_9ba6c_row14_col7,#T_9ba6c_row17_col12,#T_9ba6c_row17_col22,#T_9ba6c_row18_col7,#T_9ba6c_row18_col15,#T_9ba6c_row18_col16,#T_9ba6c_row18_col17,#T_9ba6c_row19_col21,#T_9ba6c_row19_col26,#T_9ba6c_row20_col0,#T_9ba6c_row20_col1,#T_9ba6c_row25_col15{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_9ba6c_row0_col16,#T_9ba6c_row1_col16,#T_9ba6c_row6_col16,#T_9ba6c_row14_col16,#T_9ba6c_row15_col16,#T_9ba6c_row21_col16{
#             background-color:  #6f92f3;
#             color:  #000000;
#         }#T_9ba6c_row0_col17,#T_9ba6c_row1_col17,#T_9ba6c_row7_col14,#T_9ba6c_row22_col16{
#             background-color:  #7699f6;
#             color:  #000000;
#         }#T_9ba6c_row0_col18,#T_9ba6c_row4_col17,#T_9ba6c_row24_col14,#T_9ba6c_row24_col22{
#             background-color:  #82a6fb;
#             color:  #000000;
#         }#T_9ba6c_row0_col19,#T_9ba6c_row24_col12{
#             background-color:  #6384eb;
#             color:  #000000;
#         }#T_9ba6c_row0_col21,#T_9ba6c_row0_col23,#T_9ba6c_row2_col4,#T_9ba6c_row3_col1,#T_9ba6c_row4_col0,#T_9ba6c_row4_col7,#T_9ba6c_row4_col20,#T_9ba6c_row8_col22,#T_9ba6c_row10_col1,#T_9ba6c_row10_col15,#T_9ba6c_row10_col23,#T_9ba6c_row12_col3,#T_9ba6c_row12_col24,#T_9ba6c_row13_col2,#T_9ba6c_row13_col25,#T_9ba6c_row14_col23,#T_9ba6c_row15_col21,#T_9ba6c_row15_col24,#T_9ba6c_row16_col22,#T_9ba6c_row17_col24,#T_9ba6c_row17_col25,#T_9ba6c_row18_col20,#T_9ba6c_row18_col22,#T_9ba6c_row18_col23,#T_9ba6c_row22_col7,#T_9ba6c_row24_col4{
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }#T_9ba6c_row0_col25,#T_9ba6c_row2_col20,#T_9ba6c_row6_col22,#T_9ba6c_row6_col26,#T_9ba6c_row8_col4,#T_9ba6c_row8_col20,#T_9ba6c_row10_col20,#T_9ba6c_row10_col24,#T_9ba6c_row12_col15,#T_9ba6c_row13_col24,#T_9ba6c_row15_col1,#T_9ba6c_row15_col25,#T_9ba6c_row15_col26,#T_9ba6c_row16_col0,#T_9ba6c_row16_col1,#T_9ba6c_row16_col24,#T_9ba6c_row21_col0,#T_9ba6c_row21_col1,#T_9ba6c_row21_col22,#T_9ba6c_row24_col15,#T_9ba6c_row25_col0,#T_9ba6c_row26_col0,#T_9ba6c_row26_col1{
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }#T_9ba6c_row0_col26,#T_9ba6c_row1_col26,#T_9ba6c_row2_col22,#T_9ba6c_row6_col1,#T_9ba6c_row6_col15,#T_9ba6c_row11_col15,#T_9ba6c_row11_col22,#T_9ba6c_row11_col26,#T_9ba6c_row12_col20,#T_9ba6c_row13_col4,#T_9ba6c_row14_col1,#T_9ba6c_row15_col22,#T_9ba6c_row16_col12,#T_9ba6c_row16_col20,#T_9ba6c_row17_col1,#T_9ba6c_row18_col19,#T_9ba6c_row19_col20,#T_9ba6c_row22_col15,#T_9ba6c_row23_col15,#T_9ba6c_row24_col1,#T_9ba6c_row26_col24{
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }#T_9ba6c_row1_col2,#T_9ba6c_row2_col12,#T_9ba6c_row7_col19,#T_9ba6c_row18_col2,#T_9ba6c_row25_col19{
#             b

# %%
main.head(2)
# Out:
#        gameId  season season_type  week homeTeamAbbr visitorTeamAbbr  playId  \
# 0  2018123000    2018         REG    17          BAL             CLE    2165
# 1  2018123000    2018         REG    17          BAL             CLE    2502
#
#    quarter  down  yardsToGo    nflId displayName Position collegeName  \
# 0        2     4         17  31018.0    Sam Koch        P    Nebraska
# 1        3     4         14  31018.0    Sam Koch        P    Nebraska
#
#                                      playDescription specialTeamsPlayType  \
# 0  (:42) (Punt formation) S.Koch punts 36 yards t...                 Punt
# 1  (12:50) (Punt formation) S.Koch punts 53 yards...                 Punt
#
#    playResult        ep       epa  kickReturnYardage kickType  hangTime  \
# 0          36  0.372952 -0.331417                NaN        A      4.56
# 1          16 -0.903790 -1.739167               37.0        N      4.17
#
#    kickLength  punt_inside_twenty  punt_in_endzone  punt_out_of_bounds  \
# 0        36.0                 1.0              0.0                 0.0
# 1        53.0                 0.0              0.0                 0.0
#
#    punt_downed  punt_fair_catch return_team  \
# 0          1.0              0.0         CLE
# 1          0.0              0.0         CLE
#
#                                              weather surface  wind    a    s  \
# 0  Partly Cloudy Temp: 48° F, Humidity: 59%, Wind...   grass   2.0  0.0  0.0
# 1  Partly Cloudy Temp: 48° F, Humidity: 59%, Wind...   grass   2.0  0.0  0.0
#
#       dir  dis       o      x      y
# 0  268.97  0.0  278.65  65.77  28.85
# 1  191.59  0.0   84.96  28.35  28.21

# %%
# Create new variable of average EPA grouping by various items
main['avg_epa'] = main.groupby(['down', 'yardsToGo', 'kickLength', 'weather'])['epa'].transform('mean')
main.head(2)
# Out:
#        gameId  season season_type  week homeTeamAbbr visitorTeamAbbr  playId  \
# 0  2018123000    2018         REG    17          BAL             CLE    2165
# 1  2018123000    2018         REG    17          BAL             CLE    2502
#
#    quarter  down  yardsToGo    nflId displayName Position collegeName  \
# 0        2     4         17  31018.0    Sam Koch        P    Nebraska
# 1        3     4         14  31018.0    Sam Koch        P    Nebraska
#
#                                      playDescription specialTeamsPlayType  \
# 0  (:42) (Punt formation) S.Koch punts 36 yards t...                 Punt
# 1  (12:50) (Punt formation) S.Koch punts 53 yards...                 Punt
#
#    playResult        ep       epa  kickReturnYardage kickType  hangTime  \
# 0          36  0.372952 -0.331417                NaN        A      4.56
# 1          16 -0.903790 -1.739167               37.0        N      4.17
#
#    kickLength  punt_inside_twenty  punt_in_endzone  punt_out_of_bounds  \
# 0        36.0                 1.0              0.0                 0.0
# 1        53.0                 0.0              0.0                 0.0
#
#    punt_downed  punt_fair_catch return_team  \
# 0          1.0              0.0         CLE
# 1          0.0              0.0         CLE
#
#                                              weather surface  wind    a    s  \
# 0  Partly Cloudy Temp: 48° F, Humidity: 59%, Wind...   grass   2.0  0.0  0.0
# 1  Partly Cloudy Temp: 48° F, Humidity: 59%, Wind...   grass   2.0  0.0  0.0
#
#       dir  dis       o      x      y   avg_epa
# 0  268.97  0.0  278.65  65.77  28.85 -0.331417
# 1  191.59  0.0   84.96  28.35  28.21 -1.739167

# %%
main.shape
# Out:
# (5854, 40)

# %%
main.dtypes
# Out:
# gameId                    int64
# season                    int64
# season_type              object
# week                      int64
# homeTeamAbbr             object
# visitorTeamAbbr          object
# playId                    int64
# quarter                   int64
# down                      int64
# yardsToGo                 int64
# nflId                   float64
# displayName              object
# Position                 object
# collegeName              object
# playDescription          object
# specialTeamsPlayType     object
# playResult                int64
# ep                      float64
# epa                     float64
# kickReturnYardage       float64
# kickType                 object
# hangTime                float64
# kickLength              float64
# punt_inside_twenty      float64
# punt_in_endzone         float64
# punt_out_of_bounds      float64
# punt_downed             float64
# punt_fair_catch         float64
# return_team              object
# weather                  object
# surface                  object
# wind                    float64
# a                       float64
# s                       float64
# dir                     float64
# dis                     float64
# o                       float64
# x                       float64
# y                       float64
# avg_epa                 float64
# dtype: object

# %% [markdown]
# #### Model Building

# %%
# Check for missing values
main.isnull().sum()
# Out:
# gameId                     0
# season                     0
# season_type                0
# week                       0
# homeTeamAbbr               0
# visitorTeamAbbr            0
# playId                     0
# quarter                    0
# down                       0
# yardsToGo                  0
# nflId                      0
# displayName                0
# Position                   0
# collegeName                0
# playDescription            0
# specialTeamsPlayType       0
# playResult                 0
# ep                         0
# epa                        0
# kickReturnYardage       3499
# kickType                   0
# hangTime                   6
# kickLength                 0
# punt_inside_twenty         0
# punt_in_endzone            0
# punt_out_of_bounds         0
# punt_downed                0
# punt_fair_catch            0
# return_team                4
# weather                    0
# surface                    0
# wind                    1630
# a                          0
# s                          0
# dir                        0
# dis                        0
# o                          0
# x                          0
# y                          0
# avg_epa                    0
# dtype: int64

# %%
# Sub in missing kickReturnYardage values with groupby of similar situations
main['kickReturnYardage'] = main.groupby(['down', 'yardsToGo', 'kickLength', 'weather']).transform(lambda x: x.fillna(x.mean()))
# Sub in zeros for wind since missing values most likely mean game was indoors
main['wind'] = main['wind'].replace('nan', np.nan).fillna(0)
main.head(2)
# Out:
#        gameId  season season_type  week homeTeamAbbr visitorTeamAbbr  playId  \
# 0  2018123000    2018         REG    17          BAL             CLE    2165
# 1  2018123000    2018         REG    17          BAL             CLE    2502
#
#    quarter  down  yardsToGo    nflId displayName Position collegeName  \
# 0        2     4         17  31018.0    Sam Koch        P    Nebraska
# 1        3     4         14  31018.0    Sam Koch        P    Nebraska
#
#                                      playDescription specialTeamsPlayType  \
# 0  (:42) (Punt formation) S.Koch punts 36 yards t...                 Punt
# 1  (12:50) (Punt formation) S.Koch punts 53 yards...                 Punt
#
#    playResult        ep       epa  kickReturnYardage kickType  hangTime  \
# 0          36  0.372952 -0.331417       2.018123e+09        A      4.56
# 1          16 -0.903790 -1.739167       2.018123e+09        N      4.17
#
#    kickLength  punt_inside_twenty  punt_in_endzone  punt_out_of_bounds  \
# 0        36.0                 1.0              0.0                 0.0
# 1        53.0                 0.0              0.0                 0.0
#
#    punt_downed  punt_fair_catch return_team  \
# 0          1.0              0.0         CLE
# 1          0.0              0.0         CLE
#
#                                              weather surface  wind    a    s  \
# 0  Partly Cloudy Temp: 48° F, Humidity: 59%, Wind...   grass   2.0  0.0  0.0
# 1  Partly Cloudy Temp: 48° F, Humidity: 59%, Wind...   grass   2.0  0.0  0.0
#
#       dir  dis       o      x      y   avg_epa
# 0  268.97  0.0  278.65  65.77  28.85 -0.331417
# 1  191.59  0.0   84.96  28.35  28.21 -1.739167

# %%
# Check for missing values to make sure substitutions worked correctly
main.isnull().sum()
# Out:
# gameId                  0
# season                  0
# season_type             0
# week                    0
# homeTeamAbbr            0
# visitorTeamAbbr         0
# playId                  0
# quarter                 0
# down                    0
# yardsToGo               0
# nflId                   0
# displayName             0
# Position                0
# collegeName             0
# playDescription         0
# specialTeamsPlayType    0
# playResult              0
# ep                      0
# epa                     0
# kickReturnYardage       0
# kickType                0
# hangTime                6
# kickLength              0
# punt_inside_twenty      0
# punt_in_endzone         0
# punt_out_of_bounds      0
# punt_downed             0
# punt_fair_catch         0
# return_team             4
# weather                 0
# surface                 0
# wind                    0
# a                       0
# s                       0
# dir                     0
# dis                     0
# o                       0
# x                       0
# y                       0
# avg_epa                 0
# dtype: int64

# %%
main.columns
# Out:
# Index(['gameId', 'season', 'season_type', 'week', 'homeTeamAbbr',
#        'visitorTeamAbbr', 'playId', 'quarter', 'down', 'yardsToGo', 'nflId',
#        'displayName', 'Position', 'collegeName', 'playDescription',
#        'specialTeamsPlayType', 'playResult', 'ep', 'epa', 'kickReturnYardage',
#        'kickType', 'hangTime', 'kickLength', 'punt_inside_twenty',
#        'punt_in_endzone', 'punt_out_of_bounds', 'punt_downed',
#        'punt_fair_catch', 'return_team', 'weather', 'surface', 'wind', 'a',
#        's', 'dir', 'dis', 'o', 'x', 'y', 'avg_epa'],
#       dtype='object')

# %%
# Drop columns we don't need
main = main.drop(['surface', 'weather', 'return_team', 'homeTeamAbbr', 'visitorTeamAbbr', 'nflId', 'displayName', 
                  'Position', 'collegeName', 
                  'playDescription', 'specialTeamsPlayType'], axis = 1)
main = main.dropna()
main.columns
# Out:
# Index(['gameId', 'season', 'season_type', 'week', 'playId', 'quarter', 'down',
#        'yardsToGo', 'playResult', 'ep', 'epa', 'kickReturnYardage', 'kickType',
#        'hangTime', 'kickLength', 'punt_inside_twenty', 'punt_in_endzone',
#        'punt_out_of_bounds', 'punt_downed', 'punt_fair_catch', 'wind', 'a',
#        's', 'dir', 'dis', 'o', 'x', 'y', 'avg_epa'],
#       dtype='object')

# %%
# Get dummies takes a look at all unique values and creates column for those
# Allows us to put data into numerical format
main_new = pd.get_dummies(main, columns = ['season', 'season_type', 'week','quarter', 'down', 'yardsToGo',
                                          'kickType', 'punt_inside_twenty', 'punt_in_endzone',
                                          'punt_out_of_bounds', 'punt_downed', 'punt_fair_catch'])

# %%
# Separate target variable and rest of variables
data_y = pd.DataFrame(main_new['kickReturnYardage'])
data_x = main_new.drop(['kickReturnYardage'], axis = 1)
print(data_x.columns)
print(data_y.columns)
# Out:
# Index(['gameId', 'playId', 'playResult', 'ep', 'epa', 'hangTime', 'kickLength',
#        'wind', 'a', 's', 'dir', 'dis', 'o', 'x', 'y', 'avg_epa', 'season_2018',
#        'season_2019', 'season_2020', 'season_type_REG', 'week_1', 'week_2',
#        'week_3', 'week_4', 'week_5', 'week_6', 'week_7', 'week_8', 'week_9',
#        'week_10', 'week_11', 'week_12', 'week_13', 'week_14', 'week_15',
#        'week_16', 'week_17', 'quarter_1', 'quarter_2', 'quarter_3',
#        'quarter_4', 'quarter_5', 'down_4', 'yardsToGo_1', 'yardsToGo_2',
#        'yardsToGo_3', 'yardsToGo_4', 'yardsToGo_5', 'yardsToGo_6',
#        'yardsToGo_7', 'yardsToGo_8', 'yardsToGo_9', 'yardsToGo_10',
#        'yardsToGo_11', 'yardsToGo_12', 'yardsToGo_13', 'yardsToGo_14',
#        'yardsToGo_15', 'yardsToGo_16', 'yardsToGo_17', 'yardsToGo_18',
#        'yardsToGo_19', 'yardsToGo_20', 'yardsToGo_21', 'yardsToGo_22',
#        'yardsToGo_23', 'yardsToGo_24', 'yardsToGo_25', 'yardsToGo_26',
#        'yardsToGo_27', 'yardsToGo_28', 'yardsToGo_29', 'yardsToGo_30',
#        'yardsToGo_31', 'yardsToGo_32', 'yardsToGo_34', 'yardsToGo_35',
#        'yardsToGo_41', 'yardsToGo_42', 'yardsToGo_46', 'kickType_A',
#        'kickType_N', 'kickType_R', 'punt_inside_twenty_0.0',
#        'punt_inside_twenty_1.0', 'punt_in_endzone_0.0', 'punt_in_endzone_1.0',
#        'punt_out_of_bounds_0.0', 'punt_out_of_bounds_1.0', 'punt_downed_0.0',
#        'punt_downed_1.0', 'punt_fair_catch_0.0', 'punt_fair_catch_1.0'],
#       dtype='object')
# Index(['kickReturnYardage'], dtype='object')

# %%
X_train, X_test, y_train, y_test = train_test_split(data_x, data_y, test_size = 0.3, random_state = 2)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (4093, 93)
# (1755, 93)
# (4093, 1)
# (1755, 1)

# %%
# Logistic Regression
clf = LogisticRegression()
clf.fit(X_train, y_train)
# Out:
# C:\Users\cmcle\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# LogisticRegression()

# %%
y_pred = clf.predict(X_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.0011396011396011395

# %%
y_pred
# Out:
# array([2.01910131e+09, 2.01910131e+09, 2.01910131e+09, ...,
#        2.01910131e+09, 2.01910131e+09, 2.01910131e+09])
